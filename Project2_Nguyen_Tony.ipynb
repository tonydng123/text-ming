# %% [markdown]
# # DSCI 614 - Text-Mining
# ## Project 2
# ### by Tony Nguyen

# %% [markdown]
# ## Perform google search by providing query

# %%
# import the googlesearch libary
from googlesearch import search
import pandas as pd

# povide the info for the query
query = "Winter snowstorm"

# we need to perform advanced search to get a lsit of RearchResult
# that contian the following three items:
# - title
# - url
# - description

# Get 100 search results in English using advanced search
# googlesearch will send multiple requests to go through the page by pausing about 5 seconds between the requests
results = list(search(query, num_results=100, sleep_interval=5, lang="en",advanced=True))


# Print the cleaned results
# print(results)

# %% [markdown]
# ## Convert SearchResult objects to a list of strings
#
# We can efficiently perform text mining on strings instead of SearchResult.

# %%
results = [str(item) for item in results]

# %% [markdown]
# ## Convert a list of strings to a data frame
#
# Sometime, we may need to store information in a data frame instead of a list to build some machine learning models.

# %%
data =[]
for result in results:
    # Extract URL, title, and description using string manipulation
    url = result.split("url=")[1].split(",")[0]
    title = result.split("title=")[1].split(",")[0]
    description = result.split("description=")[1].split(")")[0]
    
    # Create a dictionary for each SearchResult
    result_dict = {
        'URL': url,
        'Title': title,
        'Description': description
    }
    
    # Append the dictionary to the data list
    data.append(result_dict)

# Create the DataFrame
df = pd.DataFrame(data)

# initial check
print("Before removing anything:")
for index, row in df.iterrows():
    print(f"Original URL: {row['URL']}") 
    print(f"Original Title: {row['Title']}") 
    print(f"Original Description: {row['Description']}")
# Out:
# Before removing anything:
# Original URL: https://www.weather.gov/safety/winter-snow
# Original Title: Snow Storm Safety
# Original Description: Blizzard: Sustained winds or frequent gusts of 35 mph or more with snow and blowing snow frequently reducing visibility to less than a quarter mile for 3 hours ...
# Original URL: https://www.nssl.noaa.gov/education/svrwx101/winter/types/
# Original Title: Severe Weather 101: Winter Weather Types
# Original Description: A winter storm is a combination of heavy snow, blowing snow and/or dangerous wind chills. A winter storm is life-threatening. Blizzards are dangerous winter ...
# Original URL: https://scied.ucar.edu/learning-zone/storms/winter-storms
# Original Title: Winter Storms - UCAR Center for Science Education
# Original Description: Snowstorms are one type of winter storm. Blizzards are snowstorms with high winds, and lake effect storms are snowstorms that form near the Great Lakes.
# Original URL: https://en.wikipedia.org/wiki/Winter_storm
# Original Title: Winter storm
# Original Description: A winter storm is an event in which wind coincides with varieties of precipitation that only occur at freezing temperatures, such as snow, mixed snow and ...
# Original URL: https://www.ready.gov/winter-weather
# Original Title: Winter Weather
# Original Description: Winter storms including blizzards can bring extreme cold, freezing rain, snow, ice and high winds. A winter storm can: feature_mini img. Last a few hours or ...
# Original URL: https://www.redcross.org/get-help/how-to-prepare-for-emergencies/types-of-emergencies/winter-storm.html
# Original Title: Winter Storm Preparedness & Blizzard Safety
# Original Description: Winter storms can bring extreme cold, freezing rain, sleet, heavy snowfall, ice, and high winds. These storms can cause transportation, heat, power, ...
# Original URL: https://www.cdc.gov/disasters/winter/beforestorm/preparehome.html
# Original Title: Preparing for a Winter Storm|Winter Weather
# Original Description: Winter storms can bring cold temperatures, power failures, loss of communication services, and icy roads. To keep yourself and your loved ones safe, ...
# Original URL: https://weather.com/storms/winter
# Original Title: Snowstorm Sweeps Northeastern US
# Original Description: Jan 27, 2015 — A powerful winter storm dropped as much as 60 centimeters (almost 2 feet
# Original URL: https://www.providencejournal.com/story/news/local/2023/02/24/weather-rhode-island-snowstorm-rain-storm-clouds-gathering-tuesday/69939246007/
# Original Title: RI Weather: Major snowstorm or rain? Storm clouds ...
# Original Description: Feb 24, 2023 — What has been an all-but-snowless winter so far looks like it's going to try really hard to produce some flakes over the next week.
# Original URL: https://www.nationalgridus.com/News/2023/02/National-Grid-Preparing-for-Winter-Snowstorm-to-Impact-Massachusetts-/
# Original Title: National Grid Preparing for Winter Snowstorm to Impact ...
# Original Description: Feb 27, 2023 — WALTHAM, MA – National Grid is preparing for a winter snowstorm to impact Massachusetts Monday evening through Tuesday, ...
# Original URL: https://www.genoahealthcare.com/genoa-pharmacist-faces-winter-snowstorm-to-deliver-consumers-medications/
# Original Title: Genoa Pharmacist faces winter snowstorm to deliver ...
# Original Description: Mar 8, 2023 — When Watertown, New York, Pharmacist Meredith Sullivan made the call to close her pharmacy in preparation for an incoming snowstorm on ...
# Original URL: https://www.the-journal.com/articles/winter-snowstorm/
# Original Title: Winter snowstorm - The Journal
# Original Description: Jan 19, 2021 — A winter snow storm moved through the area on Tuesday leaving Durango under a blanket of snow.
# Original URL: https://offtheshelf.com/2021/12/winter-thrillers/
# Original Title: 10 Thrillers as Piercing as a Winter Snowstorm
# Original Description: Dec 28, 2021 — Any one of these spine-tingling thrillers will pierce you with the same amount of shock and wonder as a marvelous winter snowstorm.
# Original URL: https://www.newswise.com/articles/cell-phone-gps-data-from-february-2021-winter-snowstorm-shows-people-of-dallas-are-resilient
# Original Title: Cell phone data from winter snowstorm shows Dallas is ...
# Original Description: May 23, 2023 — Natural disasters can wreak havoc on a city, from hurricanes in Houston to winter storms in Dallas. Measuring resilience -- the length of ...
# Original URL: https://kingcounty.gov/en/legacy/depts/emergency-management/hazards/winter-storm
# Original Title: Winter storm - King County
# Original Description: Winter storms can bring wind, snow, ice, hail, thunder, lightning, and even tornadoes to the Pacific Northwest. Power outages often accompany these weather ...
# Original URL: https://www.fox6now.com/weather/bitter-cold-wisconsin-winter-snowstorm
# Original Title: Bitter cold headed for Wisconsin; winter snowstorm totals ...
# Original Description: Jan 29, 2023 — The snow from a winter storm has moved out, and now southeast Wisconsin needs to brace for bitter cold.
# Original URL: https://clipart-library.com/winter-snowstorm-cliparts.html
# Original Title: Collection of Winter Snowstorm Cliparts (40)
# Original Description: Clipart library offers about 40 high-quality Winter Snowstorm Cliparts for free! Download Winter Snowstorm Cliparts and use any clip art,coloring,png ...
# Original URL: https://www.argusleader.com/story/news/2021/12/08/sioux-falls-weather-nws-winter-storm-watch-snow-expected/6440357001/
# Original Title: NWS: Winter snowstorm expected in Sioux Falls on Friday
# Original Description: Dec 8, 2021 — Because of the pending snowstorm, NWS has placed Sioux Falls and parts of south-central South Dakota under a winter storm watch for Friday.
# Original URL: https://thekidshouldseethis.com/post/winter-snowstorm-jonas-a-time-lapse-in-manhattan
# Original Title: Winter Snowstorm Jonas
# Original Description: Jan 24, 2016 — From a window looking down upon the Upper East Side of Manhattan, watch snow accumulate in a time lapse made during winter storm Jonas, ...
# Original URL: https://www.fema.gov/sites/default/files/2020-09/PDAReportFEMA4264DRNJ.pdf
# Original Title: Severe Winter Storm and Snowstorm FEMA-4264-DR ...
# Original Description: On February 11, 2016, Governor Chris Christie requested a major disaster declaration due to a severe winter storm and snowstorm during the period of January ...
# Original URL: https://phys.org/news/2023-05-cell-winter-snowstorm-dallas-resilient.html
# Original Title: Cell phone data from winter snowstorm shows Dallas is ...
# Original Description: May 23, 2023 — From hurricanes in Houston to winter storms in Dallas, natural disasters can wreak havoc on a city. In any of these situations, ...
# Original URL: https://www.civicplus.com/blog/crm/four-reasons-a-311-crm-solution-is-your-best-defense-against-a-winter-snowstorm
# Original Title: Benefits of a 311 CRM Solution for Winter Snowstorms
# Original Description: Learn why 311 CRM solutions are invaluable in addressing resident requests and triaging responses during winter storms.
# Original URL: https://www.reddit.com/r/EASportsFC/comments/zufdsf/winter_snowstorm_pack_store_pack_guaranteed_base/
# Original Title: Winter Snowstorm Pack (Store Pack) - Guaranteed Base Icon
# Original Description: Dec 24, 2022 — 416 votes, 287 comments. 840K subscribers in the EASportsFC community. The front page of EA Sports FC & FIFA.
# Original URL: https://www.facebook.com/cityofaurorail/photos/a.236545753080931/4746998352035626/?type=3
# Original Title: City of Aurora
# Original Description: WINTER SNOWSTORM WARNING: The National Weather Service has issued a Winter Storm Warning for the area - beginning at 9 a.m. on Saturday, January 1...
# Original URL: https://dailyillini.com/news-stories/campus-life/2022/02/01/ui-moves-classes-online-due-to-winter-snowstorm/
# Original Title: UI moves classes online due to winter snowstorm
# Original Description: Feb 1, 2022 — The National Weather Service issued a notice that Champaign County will experience a winter storm with winds of up to 35 mph and an expected ...
# Original URL: https://www.krbd.org/2021/03/15/late-winter-snowstorm-in-ketchikan-wreaks-havoc-on-land-and-sea/
# Original Title: Late winter snowstorm in Ketchikan wreaks havoc on land ...
# Original Description: Late winter snowstorm in Ketchikan wreaks havoc on land and sea. Posted by Eric Stone | Mar 15, 2021. Snow berms, a somewhat rare sight in Ketchikan, ...
# Original URL: https://thebrownandwhite.com/2018/03/07/snowstorm-lehigh-close/
# Original Title: Lehigh closes for third winter snowstorm
# Original Description: Mar 7, 2018 — Third winter snowstorm causes Lehigh shutdown ... At 5:22 a.m., an LU-ALERT announced Lehigh would be closed all day Wednesday, dismissing all non ...
# Original URL: https://espo.nasa.gov/impacts/content/IMPACTS
# Original Title: IMPACTS - ESPO - NASA
# Original Description: Winter snowstorms are frequent on the eastern seaboard and cause major ... and Precipitation for Atlantic Coast-Threatening Snowstorms (IMPACTS
# Original URL: https://www.motortrend.com/reviews/2022-rivian-r1t-yearlong-review-update-5-winter-storm/
# Original Title: Rivian R1T Yearlong Review: Winter Snowstorms Tire Out ...
# Original Description: Feb 21, 2023 — As it happened, a major snowstorm rolled in, turning a simple weekend getaway into an ordeal. What follows is his account of the R1T's winter ...
# Original URL: https://modernsurvivalblog.com/natural-disaster/basic-supplies-for-a-winter-snow-storm-power-outage/
# Original Title: Preparing for a Winter Snowstorm - Basic Supplies ...
# Original Description: Jan 17, 2022 — Basic supplies to have for Survival Mode during a winter snowstorm power outage that may last days or even weeks...
# Original URL: https://www.krbd.org/2021/03/15/late-winter-snowstorm-in-ketchikan-wreaks-havoc-on-land-and-sea/
# Original Title: Late winter snowstorm in Ketchikan wreaks havoc on land ...
# Original Description: Late winter snowstorm in Ketchikan wreaks havoc on land and sea. Posted by Eric Stone | Mar 15, 2021. Snow berms, a somewhat rare sight in Ketchikan, ...
# Original URL: https://thebrownandwhite.com/2018/03/07/snowstorm-lehigh-close/
# Original Title: Lehigh closes for third winter snowstorm
# Original Description: Mar 7, 2018 — Third winter snowstorm causes Lehigh shutdown ... At 5:22 a.m., an LU-ALERT announced Lehigh would be closed all day Wednesday, dismissing all non ...
# Original URL: https://espo.nasa.gov/impacts/content/IMPACTS
# Original Title: IMPACTS - ESPO - NASA
# Original Description: Winter snowstorms are frequent on the eastern seaboard and cause major ... and Precipitation for Atlantic Coast-Threatening Snowstorms (IMPACTS
# Original URL: https://www.motortrend.com/reviews/2022-rivian-r1t-yearlong-review-update-5-winter-storm/
# Original Title: Rivian R1T Yearlong Review: Winter Snowstorms Tire Out ...
# Original Description: Feb 21, 2023 — As it happened, a major snowstorm rolled in, turning a simple weekend getaway into an ordeal. What follows is his account of the R1T's winter ...
# Original URL: https://modernsurvivalblog.com/natural-disaster/basic-supplies-for-a-winter-snow-storm-power-outage/
# Original Title: Preparing for a Winter Snowstorm - Basic Supplies ...
# Original Description: Jan 17, 2022 — Basic supplies to have for Survival Mode during a winter snowstorm power outage that may last days or even weeks...
# Original URL: https://transportation.wv.gov/DMV/News/Pages/WV-DMV-Encourages-Customers-to-Take-Advantage-of-Online-Services-During-Winter-Snowstorm.aspx
# Original Title: WV DMV Encourages Customers to Take Advantage of Online ...
# Original Description: Jan 7, 2022 — ... Division of Motor Vehicles > News > WV DMV Encourages Customers to Take Advantage of Online Services During Winter Snowstorm ...

# %% [markdown]
# ## Remove the date and time in the rearch_result using a regular expression

# %%
import re
for index, row in df.iterrows():
    '''
        Remove time as the following format
        6 PM
        6 am
        6 p.m.
        6 a.m.
        6:00 PM
        6:00 AM
        12 am
        12 pm
        12:45 AM
        12:45 PM
        12:30 a.m.
        12:34 p.m.
    '''
    removed_time = re.sub(r'\d{1,2}:?\d{0,2}\s((a|A).?(m|M).?|((p|P).?(m|M)).?)', '', row["Description"])
    ''' Remove date as the following format
        Tue February 28th 2023
        May 15
        Dec 28 2022
        February 28, 2022
    '''
    removed_date = re.sub(r'(A-Za-z]*\s)?[A-Za-z]+.?\s\d{1,2}(th)?,?( \d{4})?', '', row["Description"])
    # update Description
    row["Description"] = removed_date

# %% [markdown]
# ## Remove the hyperlink URL in the search_result using regular expression

# %%
for index, row in df.iterrows():
    # remove URL
    removed_url = re.sub(r'https?://.*', '', row["URL"])
    # update url
    row["URL"] = removed_url

# %% [markdown]
# ## Remove all words containing at most two characters such as "a", "an", "in", etc

# %%
for index, row in df.iterrows():
    
    # remove a string of length 1 or 2 characters from title
    removed_2_chars = re.sub(r'\b[a-zA-Z]{1,2}\b', '', row["Title"]) 
    # update row["Title"]
    row["Title"] = removed_2_chars
    # remove a string of length 1 or 2 characters from description
    removed_2_chars = re.sub(r'\b[a-zA-Z]{1,2}\b', '', row["Description"])
    # update row["Description"]
    row["Description"] = removed_2_chars

# %% [markdown]
# ## Remove the following five stop words: "are", "but", "very", "since", "could"

# %%
for index, row in df.iterrows():
    # remove "are"
    pattern = "are"
    remove_ = re.sub(pattern, '', row["Title"])
    # update title
    row["Title"] = remove_
    remove_ = re.sub(pattern, '', row["Description"])
    # update description
    row["Description"] = remove_
    
    # remove "but"
    pattern = "but"
    remove_ = re.sub(pattern, '', row["Title"])
    # update title
    row["Title"] = remove_
    remove_ = re.sub(pattern, '', row["Description"])
    # update description
    row["Description"] = remove_
    
    # remove "very"
    pattern = "very"
    remove_ = re.sub(pattern, '', row["Title"])
    # update tile
    row["Title"] = remove_
    remove_ = re.sub(pattern, '', row["Description"])
    # update description
    row["Description"] = remove_
    
    # remove "since"
    pattern = "since"
    remove_ = re.sub(pattern, '', row["Title"])
    # update title
    row["Title"] = remove_
    remove_ = re.sub(pattern, '', row["Description"])
    # update desctiption
    row["Description"] = remove_
    
    # remove "could"
    pattern = "could"
    remove_ = re.sub(pattern, '', row["Title"])
    # update title
    row["Title"] = remove_
    remove_ = re.sub(pattern, '', row["Description"])
    # update description
    row["Description"] = remove_

# %% [markdown]
# ## Remove all special characters, punctuation using regular expression

# %%
for index, row in df.iterrows():
    # remove not character and not space from row["Title"] and row["Description"]
    remove_ = re.sub(r'[^\w\s]', '', row["Title"])
    # update title
    row["Title"] = remove_
    remove_ = re.sub(r'[^\w\s]', '', row["Description"])
    # update description
    row["Description"] = remove_
    
# final check
print("After removing all above things:")
for index, row in df.iterrows():
    print(f"New URL: {row['URL']}") 
    print(f"New Title: {row['Title']}") 
    print(f"New Description: {row['Description']}")
# Out:
# After removing all above things:
# New URL:
# New Title: Snow Storm Safety
# New Description: Blizzard Sustained winds  frequent gusts  mph  more with snow and blowing snow frequently reducing visibility  less than  quarter mile  hours
# New URL:
# New Title: Severe Weather 101 Winter Weather Types
# New Description:  winter storm   combination  heavy snow blowing snow and dangerous wind chills  winter storm  lifethreatening Blizzards  dangerous winter
# New URL:
# New Title: Winter Storms  UCAR Center for Science Education
# New Description: Snowstorms  one type  winter storm Blizzards  snowstorms with high winds and lake effect storms  snowstorms that form near the Great Lakes
# New URL:
# New Title: Winter storm
# New Description:  winter storm   event  which wind coincides with varieties  precipitation that only occur  freezing temperatures such  snow mixed snow and
# New URL:
# New Title: Winter Weather
# New Description: Winter storms including blizzards can bring extreme cold freezing rain snow ice and high winds  winter storm can feature_mini img Last  few hours
# New URL:
# New Title: Winter Storm Prepdness  Blizzard Safety
# New Description: Winter storms can bring extreme cold freezing rain sleet heavy snowfall ice and high winds These storms can cause transportation heat power
# New URL:
# New Title: Preparing for  Winter StormWinter Weather
# New Description: Winter storms can bring cold temperatures power failures loss  communication services and icy roads  keep yourself and your loved ones safe
# New URL:
# New Title: Winter Storm  The Weather Channel  weathercom
# New Description:  Winter Storm Olive moved through Michigan knocking down trees one Ann Arbor  These Eagle Pnts Had  Important Task Even During  Snowstorm
# New URL:
# New Title: 90000 lose power  yet another winter storm brings
# New Description:   Slick streets from the current snowstorm and Sunday night snow  Seattle have prompted Metro  run  Emergency Snow Network which
# New URL:
# New Title: LateWinter Storm Brings Heavy Snow and Rain  the
# New Description:    major storm dropped more than two feet  snow  portions  northwest Massachusetts and southern Vermont while some cities only saw
# New URL:
# New Title: Winter storm set  impact millions stretching from the West
# New Description:    massive winter storm bringing  mix  heavy snow rain and gusty winds  poised  lash much  the  West and North this week and has
# New URL:
# New Title: Snowstorm  snarl travel across Midwest
# New Description: Flight delays and cancellations began mounting  Wednesday  the second winter storm  the week dropped snowfall
# New URL:
# New Title: Nationwide winter storm set  bring ething from
# New Description:    large winter storm slammed into the western  over the weekend blanketing mountain as with heavy snow and  now set  traverse the
# New URL:
# New Title: Big mess  days away Major winter storm  bring snow
# New Description:   Bitterly cold temperatures and  significant winter snowstorm  threaten holiday travel plans for millions across the  from the
# New URL:
# New Title: How Winter Storms Form
# New Description: How  blizzards form  blizzard   longlasting snowstorm with  strong winds and intense snowfall You need three things  have  blizzard cold air
# New URL:
# New Title: Massive winter storm
# New Description:   According  the FOX Forecast Center blizzard conditions  likely Thursday and Friday  snowstorm must reach the following criteria
# New URL:
# New Title: Massive winter storm  impact entire Lower 48
# New Description:   The Twin Cities were forecast  see one  their biggest snowstorms  record with travel becoming difficult  impossible Wednesday
# New URL:
# New Title: CLASSIFICATION  WINTER SNOWSTORMS
# New Description: MidAtlantic Winter Storm Patterns Miller  type snowstorm This type  snowstorm has  low which originates  the Gulf  intensifies and races  the
# New URL:
# New Title: Winter Snowstorm Wish
# New Description: Winter Snowstorm Wish Winter Storm Wish  know that   not alone when  fire   computer  the morning and feel instantly overwhelmed
# New URL:
# New Title: The Worst Snowstorms  United States History
# New Description: You probably even have  memory  your own worst snowstorm  when the snow piled  The 22 North American Winter Storm was  bomb cyclone that
# New URL:
# New Title:  New Winter Storm with Heavy Snow and Blizzard tracks
# New Description:   Another major winter storm Diaz  shaping  for the northern United States this week associated with  large upper low emerging from the
# New URL:
# New Title: Wisconsin snowstorm weather forecast
# New Description:    winter storm warning for Milwaukee County and its surrounding as took   Thursday and  set  stretch   Saturday
# New URL:
# New Title: More than 200 people stayed  Seattle emergency
# New Description:   When temperatures dropped below freezing earlier this month amid  winter snowstorm more 0 people sought shelter inside emergency
# New URL:
# New Title: States  emergency decld  Southeast ahead  winter
# New Description:   States  emergency decld  Southeast ahead  winter snowstorm  million Americans  under some type  weather alert
# New URL:
# New Title:  Impossible  Forget These 7 Horrific Winter Storms
# New Description:   E now and again winter storms  Washington state can get   The 12 snowstorm that blanketed the entire Pacific Northwest
# New URL:
# New Title: 100 Free Snowstorm  Blizzard Images
# New Description: Snowstorm photos for download All pictures  free  use Royaltyfree images Free Winter Girl illustration and picture
# New URL:
# New Title: Can lightning occur  the winter  when   snowing
# New Description: Strong winter snowstorms and blizzards commonly produce lightning strikes  phenomenon referred   thundersnow Lightning and thunder can occur with
# New URL:
# New Title: Strongest snowstorm  years leaves Californians
# New Description:   Snow  seen  the hills around the San Francisco Bay a   strong
# New URL:
# New Title: Satellite tracks intense winter snowstorm across  East
# New Description:   Satellites  orbit have captured stunning views  the powerful Noreaster that dropped snow   wide swath  the  Northeast
# New URL:
# New Title: Blizzard  2022 Leaves More Than 2 Feet  Snow
# New Description:   This  now the seventh biggest snowstorm  all time  Boston  This winter has been absolutely crazy  97  the total snowfall for
# New URL:
# New Title: Another Friday Snowstorm Likely across West Michigan
# New Description:   Winter Weather Impacts for 10 2023 Weather Snowstorm likely for West Michigan this Friday Heavy wet snow  likely Thursday
# New URL:
# New Title: Snow Storm Essentials Checklist How  Stock
# New Description: Stock   these winter essentials  you prepd for  snowstorm before  hits
# New URL:
# New Title: Winter snowstorm hits northern Arizona
# New Description:   Flagstaff was hit with several inches  snow   just  week after another storm dumped snow  the northern Arizona town
# New URL:
# New Title: Winter snowstorm targets Minnesota 6plus inches possible
# New Description:   Winter snowstorm targets plus inches possible  warm mostly quiet day Wednesday before rain snow and ice move
# New URL:
# New Title: Cell phone data from winter snowstorm shows Dallas
# New Description: Cell phone data from winter snowstorm shows Dallas  resilient  GPS locations  anonymous cellphone users IDs
# New URL:
# New Title: Winter Storm 2021  Texas power outage
# New Description:  Texas faced recordlow temperatures  21 and snow and ice made roads impassable the state electric grid operator lost control  the power
# New URL:
# New Title: Another Pacific winter snowstorm hits California
# New Description:   Pacific winter snowstorm this week   year when snowfall  California has already exceeded yearly totals  Pacific winter storm has the
# New URL:
# New Title: Snow Storm   Jar
# New Description:   Fun and easy winter science activities for kids  try  Kids will love creating their own snowstorms with common household supplies
# New URL:
# New Title: Winter Snowstorm Hits Shoreline Communities
# New Description:   NBC Universal Inc People across the state  preparing for the incoming snowstorm Several inches  snow  expected  fall overnight
# New URL:
# New Title:  not winter yet
# New Description:    not winter yet  Midwest snowstorm  headed toward Northeast Areas near Buffalo  see multiple feet from lakeeffect snows late
# New URL:
# New Title: The mystery behind thundersnow
# New Description:   Though thunder and lightning   snowstorm   predictor  heavy snowfall researchers have recently learned heavy snowfall  not
# New URL:
# New Title: Winter Storm Olive CrossCountry Trek Will Pack Blizzard
# New Description: live   one  the heaviest snowstorms  years for parts  the upper Midwest including Minneapolis Paul where the National Weather Service
# New URL:
# New Title: Extreme Cold and Snowstorms  readydc  gov
# New Description: Winter storms may include high wind freezing rain heavy snowfall and extreme cold Severe winter storms can cause blocked roads power outages
# New URL:
# New Title: Blizzard
# New Description:   Blizzards  not just bad snowstorms they  specific types    typical winter weather  snowstorm   severe blizzard
# New URL:
# New Title: New York City wakes   biggest snowfall  season
# New Description:    new coastcoast winter storm  forecast  pummel parts    still likely the biggest snowstorm  the season the NWS said
# New URL:
# New Title: Winter snowstorm headed  eastern Idaho Wednesday
# New Description:   IDAHO FALLS   winter storm  headed towards eastern Idaho Wednesday morning The National Weather Service  Pocatello  forecasting
# New URL:
# New Title: Severe Winter Weather
# New Description:  normally experience mild winters can  hit with  major snowstorm  extreme cold Winter storms can result  flooding storm surge closed highways
# New URL:
# New Title: Winter Snowstorm  Art Glass Vase
# New Description: Discover Winter Snowstorm  Orient  Flume Art Glass and get inspired  more original art and unique treasures created  artists Shop now
# New URL:
# New Title: Blizzard Weather Warning Colorado Braces for Major
# New Description:   The National Weather Service forecast map shows the path  the major winter snowstorm about  hit central  states NWS
# New URL:
# New Title: Activity Major Winter Snowstorm
# New Description: Two smaller snowstorms followed the Blizzard and finally rain and milder weather  later January led  severe flooding  New York Pennsylvania and Maryland
# New URL:
# New Title: Top 25 Snowfalls  the Twin Cities 18842023
# New Description: Below  have listed  largest snowfall events  snowstorms
# New URL:
# New Title: Winter Snowstorm Closes Roads  Wyoming
# New Description:    powerful late winter snowstorm intensified over the central Rocky Mountains  Sunday with heavy snow and wind leading  airport and road
# New URL:
# New Title: Long Island winter snowstorm season  just beginning
# New Description:    halfway through meteorological winter   feels like  hasn even started Temperatures sod  degrees  Islip  Jan
# New URL:
# New Title: Winter Storms
# New Description: Winter Storms Before  Winter Storm Weather forecasts usually let you know ahead  time  there   winter storm coming
# New URL:
# New Title: Snowstorm
# New Description: Back  the olden days  was  small feat  take our beer  wagon  the local establishments especially  the dead  winter  had  find inventive
# New URL:
# New Title: IRS announces tax relief for victims  severe winter storm
# New Description: 202304   Victims  the severe winter storm and snowstorm beginning  and ending  now have until
# New URL:
# New Title: Incoming snowstorm sends Metro Detroit under winter
# New Description:    winter weather advisory has been issued for Metro Detroit Thursday night and Friday due   approaching storm that  leave behind
# New URL:
# New Title: Major snowstorm buries Utah Snow totals
# New Description:    winter storm warning remains  effect   with additional accumulations 9 inches possible  the Salt Lake Valley along with
# New URL:
# New Title: Recap  Each Winter Snowstorms  New York 1950
# New Description: This was the third major snowstorm  the winter However those storms were characterized   cold temperatures while this storm saw temperatures rise from
# New URL:
# New Title: Winter Snowstorm Hits Parts  Oregon and Washington
# New Description:   The National Weather Service Tyler Krantz tells    have those winter storm warnings  effect  the Cascade Mountains including the
# New URL:
# New Title: Predicted winter snowstorm fizzles out into  slushy wintry
# New Description:     winter storm that was forecast  drop more  inches  snow  Columbus Wednesday fizzled out into  slushy mess  rain and freezing
# New URL:
# New Title: Keep Safe During  Major Winter Snowstorm
# New Description:   Keep Safe During  Major Winter Snowstorm  Hospital emergency departments see  influx  weatherrelated injuries with each snowstorm
# New URL:
# New Title: Help  Crews work  get supplies  stranded residents
# New Description:     get muchneeded supplies  Southern California mountain communities days after  series  r winter snowstorms struck the region
# New URL:
# New Title: Worst Snowstorms  New England History
# New Description:  fact  meteorologists efforts  measure the intensity  winter storms     with earthquakes and hurricanes  began 06 with the Northeast
# New URL:
# New Title: Winter snowstorm  School closures
# New Description:   Winter snowstorm  School closures parking bans and municipal  According  the National Weather Service  winter storm warning has
# New URL:
# New Title: Early March winter snowstorm hitting  Louis Sunday
# New Description:   Forecast  accumulating sleet  snow  Sunday night weather Early March winter snowstorm hitting  Louis Sunday Major winter storm aiming
# New URL:
# New Title: Southern New Englanders take late winter snowstorm
# New Description:   Southern New Englanders take late winter snowstorm  stride  ALLEGRA ZAMORE  NEWS Tue  1055  PST
# New URL:
# New Title:  slight chance  snow Monday before  winter snowstorm
# New Description:   This  due   pretty sizable snowstorm entering Western Wisconsin  Winter Storm Watch   effect starting Tuesday
# New URL:
# New Title: Winter snowstorm hits Northeast
# New Description:    winter snowstorm hit the  Northeast  Saturday morning causing power outages  the region and forcing the cancellation  thousands
# New URL:
# New Title: Wyoming Slammed With Late Winter Snowstorm
# New Description:   Wyoming Slammed With Late Winter Snowstorm Roads Closed Across State Snowfall totals ranged from several inches  two feet
# New URL:
# New Title: Historic winter snowstorm turns deadly  Oregon
# New Description: Historic winter snowstorm turns deadly  Oregon freezing temperatures persist  KATU Staff Thu 23 358  PST UserWay icon for
# New URL:
# New Title: 25 Synonyms  Antonyms for SNOWSTORM
# New Description: There  and Old Man Winter sit and smoke and lay their plans for the next snowstorm  The Pilgrims now continued their explorations  the midst   driving
# New URL:
# New Title: Super Bowl weekend winter snowstorm
# New Description:    winter storm  potentially going  target the East Coast over the weekend and linger into Monday Weather forecasting models  coming
# New URL:
# New Title: Snowstorm Sweeps Northeastern
# New Description:    powerful winter storm dropped  much  centimeters  feet
# New URL:
# New Title:  Weather Major snowstorm  rain Storm clouds
# New Description:   What has been  allsnowless winter  far looks like  going  try really hard  produce some flakes over the next week
# New URL:
# New Title: National Grid Preparing for Winter Snowstorm  Impact
# New Description:   WALTHAM   National Grid  preparing for  winter snowstorm  impact Massachusetts Monday evening through Tuesday
# New URL:
# New Title: Genoa Pharmacist faces winter snowstorm  deliver
# New Description:   When Watertown New York Pharmacist Meredith Sullivan made the call  close her pharmacy  preparation for  incoming snowstorm
# New URL:
# New Title: Winter snowstorm  The Journal
# New Description:    winter snow storm moved through the a  Tuesday leaving Durango under  blanket  snow
# New URL:
# New Title: 10 Thrillers  Piercing   Winter Snowstorm
# New Description:   Any one  these spinetingling thrillers will pierce you with the same amount  shock and wonder   marvelous winter snowstorm
# New URL:
# New Title: Cell phone data from winter snowstorm shows Dallas
# New Description:   Natural disasters can wreak havoc   city from hurricanes  Houston  winter storms  Dallas Measuring resilience  the length
# New URL:
# New Title: Winter storm  King County
# New Description: Winter storms can bring wind snow ice hail thunder lightning and even tornadoes  the Pacific Northwest Power outages often accompany these weather
# New URL:
# New Title: Bitter cold headed for Wisconsin winter snowstorm totals
# New Description:   The snow from  winter storm has moved out and now southeast Wisconsin needs  brace for bitter cold
# New URL:
# New Title: Collection  Winter Snowstorm Cliparts 40
# New Description: Clipart library offers  highquality Winter Snowstorm Cliparts for free Download Winter Snowstorm Cliparts and use any clip artcoloringpng
# New URL:
# New Title: NWS Winter snowstorm expected  Sioux Falls  Friday
# New Description:   Because  the pending snowstorm NWS has placed Sioux Falls and parts  southcentral South Dakota under  winter storm watch for Friday
# New URL:
# New Title: Winter Snowstorm Jonas
# New Description:   From  window looking down upon the Upper East Side  Manhattan watch snow accumulate   time lapse made during winter storm Jonas
# New URL:
# New Title: Severe Winter Storm and Snowstorm FEMA4264
# New Description:   Governor Chris Christie requested  major disaster declaration due   severe winter storm and snowstorm during the period  January
# New URL:
# New Title: Cell phone data from winter snowstorm shows Dallas
# New Description:   From hurricanes  Houston  winter storms  Dallas natural disasters can wreak havoc   city  any  these situations
# New URL:
# New Title: Benefits   311 CRM Solution for Winter Snowstorms
# New Description: Learn 1 CRM solutions  invaluable  addressing resident requests and triaging responses during winter storms
# New URL:
# New Title: Winter Snowstorm Pack Store Pack  Guaranteed Base Icon
# New Description:   416 7 0K subscribers  the EASportsFC community The front page   Sports   FIFA
# New URL:
# New Title: City  Aurora
# New Description: WINTER SNOWSTORM WARNING The National Weather Service has issued  Winter Storm Warning for the a  beginning    Saturday
# New URL:
# New Title:  moves classes online due  winter snowstorm
# New Description:   The National Weather Service issued  notice that Champaign County will experience  winter storm with winds    mph and  expected
# New URL:
# New Title: Late winter snowstorm  Ketchikan wreaks havoc  land
# New Description: Late winter snowstorm  Ketchikan wreaks havoc  land and sea Posted  Eric Stone   Snow berms  somewhat r sight  Ketchikan
# New URL:
# New Title: Lehigh closes for third winter snowstorm
# New Description:   Third winter snowstorm causes Lehigh shutdown  22   ALERT announced Lehigh would  closed all day Wednesday dismissing all non
# New URL:
# New Title: IMPACTS  ESPO  NASA
# New Description: Winter snowstorms  frequent  the eastern seaboard and cause major  and Precipitation for Atlantic CoastThreatening Snowstorms IMPACTS
# New URL:
# New Title: Rivian R1T Yearlong Review Winter Snowstorms Tire Out
# New Description:     happened  major snowstorm rolled  turning  simple weekend getaway into  ordeal What follows  his account  the R1T winter
# New URL:
# New Title: Preparing for  Winter Snowstorm  Basic Supplies
# New Description:   Basic supplies  have for Survival Mode during  winter snowstorm power outage that may last days  even weeks
# New URL:
# New Title: Late winter snowstorm  Ketchikan wreaks havoc  land
# New Description: Late winter snowstorm  Ketchikan wreaks havoc  land and sea Posted  Eric Stone   Snow berms  somewhat r sight  Ketchikan
# New URL:
# New Title: Lehigh closes for third winter snowstorm
# New Description:   Third winter snowstorm causes Lehigh shutdown  22   ALERT announced Lehigh would  closed all day Wednesday dismissing all non
# New URL:
# New Title: IMPACTS  ESPO  NASA
# New Description: Winter snowstorms  frequent  the eastern seaboard and cause major  and Precipitation for Atlantic CoastThreatening Snowstorms IMPACTS
# New URL:
# New Title: Rivian R1T Yearlong Review Winter Snowstorms Tire Out
# New Description:     happened  major snowstorm rolled  turning  simple weekend getaway into  ordeal What follows  his account  the R1T winter
# New URL:
# New Title: Preparing for  Winter Snowstorm  Basic Supplies
# New Description:   Basic supplies  have for Survival Mode during  winter snowstorm power outage that may last days  even weeks
# New URL:
# New Title:  DMV Encourages Customers  Take Advantage  Online
# New Description:    Division  Motor Vehicles  News   DMV Encourages Customers  Take Advantage  Online Services During Winter Snowstorm
